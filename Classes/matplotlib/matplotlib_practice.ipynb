# %%
'''
Import statements.
'''
from sklearn import datasets
import pandas as pd
import matplotlib.pyplot as plt

# %%
'''
Import dataset and take a peek.
'''
data = datasets.load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)
df["target"] = data.target
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
'''

'''
df["target"].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# ## Start Visualizations

# %%
'''
Let's look at the distribution of our output variable.
We want a balanced dataset for modelling.
'''
plt.hist(df["target"])
plt.title("Distribution of Output Values")
plt.xlabel("Value")
plt.ylabel("Count")
plt.xticks([0, 1, 2])
# Out:
# ([<matplotlib.axis.XTick at 0x7fc0d0824dc0>,
# ...
#  [Text(0, 0, ''), Text(0, 0, ''), Text(0, 0, '')])

# %%
plt.plot(df["sepal length (cm)"], df["sepal width (cm)"] )
